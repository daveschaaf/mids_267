# %% [markdown]
# # Assignment 5 - Run 2 Evaluation

# %% [markdown]
# ===========================================================================================================

# %% [markdown]
# ## 1. Setup
#
# We will first install a number of libraries and import what we will need.

# %%
from google.colab import userdata

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%capture
# !pip install -q -U langchain langchain-community langchain-huggingface langchain-qdrant
# !pip install -q -U qdrant-client sentence-transformers arxiv pymupdf
# !pip install -q -U transformers accelerate bitsandbytes

# !pip install -q -U xmltodict

# !pip install -q -U cohere

# !pip install -q -U langchain-cohere

# !pip install bert_score

# %%
import os
import numpy as np
import time
import locale

# IMPORTANT: Add your Hugging Face token to Colab's Secrets (the key icon on the left panel)
# and name it 'HF_TOKEN', or replace the line below with os.environ["HF_TOKEN"] = "your_token"
os.environ["HF_TOKEN"] = userdata.get('HF_TOKEN')

import langchain
from langchain_community.document_loaders import ArxivLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings, HuggingFacePipeline
from langchain_qdrant import QdrantVectorStore

from qdrant_client import QdrantClient
from qdrant_client.http.models import Distance, VectorParams
from langchain_core.prompts import PromptTemplate
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser, JsonOutputParser
from langchain_core.utils.function_calling import convert_to_openai_tool


from langchain_community.document_loaders import ArxivLoader
from langchain_community.document_loaders import PyMuPDFLoader

import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline, BitsAndBytesConfig


from langchain_cohere import ChatCohere

import torch.nn.functional as F
from torch import Tensor
from transformers import AutoModel

import bs4
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.document_loaders import TextLoader
from langchain_community.document_loaders import WikipediaLoader

locale.getpreferredencoding = lambda: "UTF-8"

# %%
from typing import Annotated, Literal, TypedDict
from langchain_core.messages import HumanMessage, AIMessage, ToolMessage, BaseMessage, SystemMessage
from langchain_core.tools import tool
from langgraph.graph import StateGraph, START, END
from langgraph.prebuilt import ToolNode
from langchain_huggingface import HuggingFacePipeline, ChatHuggingFace
from transformers.utils import get_json_schema
import json
import re
import uuid

# %%
# %%capture
# !pip install -U sentence_transformers
from sentence_transformers import CrossEncoder


# !tar -xzf "/content/drive/MyDrive/Colab Data/MIDS-267-A5/qdrant_250_50.tar.gz" -C /content

# %%
# %%capture

import shutil

class VectorStoreRetriever():
      EMBEDDINGS_MODEL = 'sentence-transformers/multi-qa-mpnet-base-dot-v1'
      def __init__(self):
          self.collection_name = "rag_tech_db_250"
          self.qdrant_path = '/content/qdrant_storage'
          self.init_embeddings(self.EMBEDDINGS_MODEL)
          self.init_vector_store(self.qdrant_path, self.collection_name)
      def init_vector_store(self, path, collection_name):
          self.vector_store = QdrantVectorStore(
              client=QdrantClient(path=self.qdrant_path),
              embedding=self.embeddings,
              collection_name=collection_name,
              distance=Distance.DOT)
      def init_embeddings(self, embeddings_model):
          self.embeddings = HuggingFaceEmbeddings(model_name=embeddings_model)

      def destroy(self):
          self.vector_store.client.delete_collection(self.collection_name)
          if os.path.exists(self.qdrant_path):
              shutil.rmtree(self.qdrant_path)
              print(f"Qdrant storage directory removed ({self.qdrant_path}).")

retriever = VectorStoreRetriever()
vector_store = retriever.vector_store
embedings = retriever.embeddings

# %%
# %%capture

import warnings
warnings.filterwarnings('ignore')

from transformers import GenerationConfig

# LOAD QWEN 3 LLM
qwen_model_name = "Qwen/Qwen3-4B-Instruct-2507"

qwen_quantization_config = BitsAndBytesConfig(
   load_in_4bit=True,
   bnb_4bit_quant_type="nf4",
   bnb_4bit_use_double_quant=True,
   bnb_4bit_compute_dtype=torch.bfloat16
)

qwen_tokenizer = AutoTokenizer.from_pretrained(qwen_model_name)
qwen_model = AutoModelForCausalLM.from_pretrained(
    qwen_model_name,
    dtype=torch.float32,
    device_map="auto",
    quantization_config=qwen_quantization_config
)
qwen_model.config.pad_token_id = qwen_model.config.eos_token_id

# %%
qwen_pipe = pipeline(
    "text-generation",
    model=qwen_model,
    tokenizer=qwen_tokenizer,
    max_new_tokens=1000,
    temperature=0.3,
    top_p=0.5,
    do_sample=True,
    repetition_penalty=1.2,
    pad_token_id=qwen_model.config.eos_token_id,
    eos_token_id=qwen_model.config.eos_token_id
)

qwen_llm = HuggingFacePipeline(pipeline=qwen_pipe)
qwen_chat = ChatHuggingFace(llm=qwen_llm)

# %%
class EvaluatorConfig(TypedDict):
    name: str
    template: str
    generation_config: dict

# %%
IDK = "[IDK]"

claims_config = EvaluatorConfig(
    name='claims',
    template="""Your task is to evaluate the claims of a provided statement based ONLY on provided context.

A claim is a single, simplified and separable clause that can be evaluated independently.
You must break the statement into its constituent claims independently of the context.

After the statement is broken into claims, classify each in exactly 1 of 3 possible categories: faithful, noisy, or irrelevant.
A claim is faithful if it is supported or verified by the supplied context. The factual basis of a faithful claim MUST appear in the context.
A claim is noisy if it is incorrect, factually wrong, or contrary to the information in the context.
Claims that are not noisy and not faithful are irrelevant - the context does not mention the information in the claim, so it cannot be determined as noisy or faithful to the context.

Context:
Frogs are green.

Statement:
Darryl is a frog, therefore he is green. Frogs are brown.

Answer:
{{
"claims": [{{ "claim":"Darryl is a frog", "evaluation":"faithful" }},
           {{ "claim": "he is green", "evaluation": "irrelevant" }},
           {{ "claim": "Frogs are brown", "evaluation": "noisy" }}],
"claims_count": 3,
"noisy_count": 1,
"faithful_count": 1,
"irrelevant_count": 1
}}

Context:
{context}

Statement:
{response}

Your response MUST be a valid JSON object enclosed in markdown tags structured with this schema:
```json
{{
"claims": array[{{ "claim":"string","evaluation":string["faithful","noisy","irrelevant"] }}],
"claims_count": integer (total count of all claims),
"noisy_count": integer (count of noisy claims),
"faithful_count": integer (count of faithful claims),
"irrelevant_count": integer (count of irrelevant claims)
}}
```""",
    generation_config={
        "max_new_tokens": 1024,
        "do_sample": False,
    }
)
persona_config = EvaluatorConfig(
    name='persona',
    template="""Your task is to evaluate how well a statement reflects the communication preferences of the user.
There are 2 types of users - Researchers and Marketers - each with slightly different communication preferences.

Your evaluation must be an integer in 0 or 1:
0 - Statement more closely reflects the UNacceptable criteria
1 - Statement more closely reflects the acceptable criteria

Preferences:
{persona}

Statement:
{response}

Your response MUST be a valid JSON object enclosed in markdown tags structured with this schema:
```json
{{
"length": {{"evaluation": "descibe how the Statement fits the length preference", "score": integer[0,1]}},
"vocabulary": {{"evaluation": "descibe how the Statement fits the relevant vocabulary preference", "score": integer[0,1]}},
"technical_depth": {{"evaluation": "descibe how the Statement fits the technical depth preference", "score": integer[0,1]}},
"relevant_topics": {{"evaluation": "descibe how the Statement fits the relevant topics preference", "score": integer[0,1]}},
"tone": {{"evaluation": "descibe how the Statement fits the tone preference", "score": integer[0,1]}},
}}
```"""
,
    generation_config={
        "max_new_tokens": 1024,
        "do_sample": False,
    }
)
relevancy_config = EvaluatorConfig(
    name='relevancy',
    template="""You are test writing specialist. You will be given a statement that is the intended answer to a question.
Your task is to write a question based ONLY on the content of the statement.
When paired together, the statement should be a reasonable and accurate answer to the question.

Statement:
{response}


Provide 3 DIFFERENT questions. Write ONLY the questions. Do not provide any other text or answer to the question.
Your response MUST be a valid JSON object enclosed in markdown tags structured with this schema:
```json
{{
"questions": ["question 1","question 2","question 3"]
}}
```"""
,
    generation_config={
        "max_new_tokens": 1024,
        "top_p": 0.95,
        "temperature": 1.0,
        "do_sample": True,
    }
)

# %%
import bert_score
import gc
from sklearn.metrics.pairwise import cosine_similarity

class RAGEvaluator():
    def __init__(self, tokenizer, model, embeddings, vector_store, idk, claims_config=None, persona_config=None, relevancy_config=None):
        self.tokenizer = tokenizer
        self.model = model
        self.embeddings = embeddings
        self.vector_store = vector_store
        self.idk = idk
        self.claims_config = claims_config
        self.persona_config = persona_config
        self.relevancy_config = relevancy_config
        self.faithful_scores = []
        self.noisy_scores = []
        self.persona_scores = []
        self.relevancy_scores = []
    def evaluate(self, eval_qas):
        questions = []
        gold_answers = []
        context_ids = []
        responses = []
        response_personas = []
        response_times = []
        lengths = []
        for qa in eval_qas:
            questions.append(qa['question'])
            gold_answers.append(qa['gold_answer'])
            responses.append(qa['response'])
            response_personas.append(qa['persona'])
            context_ids.append(qa['context_metadata'])
            response_times.append(qa['duration'])
            lengths.append(len(qa['response']))

        print("Begin RAG Evaluation")
        bert_answers = []
        bert_responses = []
        idk_count = 0
        for question, gold_answer, context, response, persona in zip(questions, gold_answers, context_ids, responses, response_personas):
            if self.idk in response:
                idk_count += 1
                print(f"Question: {question}")
                print(f"Skipping {self.idk} response")
                print("------")
                continue
            bert_answers.append(gold_answer)
            bert_responses.append(response)
            print(f"Response: {response}")
            print(f"Gold Answer ({persona['name']}): {gold_answer}")
            self.claims(response, context)
            self.persona(response, persona['description'])
            self.relevancy(response, question)
            print("------")
        evaluation = {
            "faithfulness": np.mean(self.faithful_scores),
            "noisiness": np.mean(self.noisy_scores),
            "persona": np.mean(self.persona_scores),
            "relevancy": np.mean(self.relevancy_scores),
            "response_time": np.mean(response_times),
            "length": np.mean(lengths)
        }
        evaluation["hallucination"] = self.hallucination(responses, context_ids)
        evaluation["bert"] = self.bert(bert_answers, bert_responses) # Skips IDK
        idk_rate = idk_count/len(questions)
        evaluation["idk_rate"] = idk_rate
        print("*"*60)
        print(f"FULL EVALUATION")
        print("--------------------------")
        print(f"Faithfulness: {evaluation['faithfulness']:.3f}")
        print(f"Noisiness: {evaluation['noisiness']:.3f}")
        print(f"Persona: {evaluation['persona']:.3f}")
        print(f"Relevancy: {evaluation['relevancy']:.3f}")
        print(f"Hallucination: {evaluation['hallucination']['accuracy']:.3f}")
        print(f"BERT Score: {evaluation['bert']['f1']:.3f}")
        print(f"Response Time: {evaluation['response_time']:.3f}")
        print(f"Length: {evaluation['length']:.3f}")
        print(f"IDK Rate: {idk_rate:.3f}")
        print("*"*60)
        return evaluation
    def claims(self, response: str, context_ids: str):
        context_records = self.vector_store.client.retrieve(
            ids=context_ids,
            collection_name=self.vector_store.collection_name,
            with_payload=True
        )
        context = "\n\n".join([record.payload['page_content'] for record in context_records])
        template_fill = {
            "response": response,
            "context": context
        }
        template = self.claims_config['template']
        generation_config = self.claims_config['generation_config']
        claims_evaluation = self.invoke(template, template_fill, generation_config)
        claim_count = claims_evaluation['claims_count']
        if claim_count == 0:
            faithful = 0
            noisy = 0
        else:
            faithful_count = claims_evaluation['faithful_count']
            noisy_count = claims_evaluation['noisy_count']
            faithful = faithful_count/claim_count
            noisy = noisy_count/claim_count
        print(f"Faithful: {faithful:.3f}")
        print(f"Noisy: {noisy:.3f}")
        self.faithful_scores.append(faithful)
        self.noisy_scores.append(noisy)
        gc.collect()
        torch.cuda.empty_cache()
    def persona(self, response: str, persona: str):
        template_fill = {
            "response": response,
            "persona": persona
        }
        template = self.persona_config['template']
        generation_config = self.persona_config['generation_config']
        persona_evaluation = self.invoke(template, template_fill, generation_config)
        persona_scores = [1 if float(x['score']) >= 0.5 else 0 for x in persona_evaluation.values()]
        persona_score = np.mean(persona_scores)
        print(f"Persona: {persona_score:.3f}")
        print(f"{persona_evaluation}")
        self.persona_scores.append(persona_score)
    def relevancy(self, response: str, question: str):
        template_fill = {
            "response": response
        }
        template = self.relevancy_config['template']
        generation_config = self.relevancy_config['generation_config']
        relevancy_evaluation = self.invoke(template, template_fill, generation_config)
        embed_question = self.embeddings.embed_query(question)
        similarity_scores = []
        for n, rel_question in enumerate(relevancy_evaluation['questions']):
            embed_rel_question = self.embeddings.embed_query(rel_question)
            similarity_scores.append(cosine_similarity([embed_question], [embed_rel_question])[0][0])
        relevancy = np.mean(similarity_scores)
        print(f"Relevancy: {relevancy:.3f}")
        self.relevancy_scores.append(relevancy)
    def hallucination(self, responses: list[str], context: list[str]):
        """Measures the tool calling """
        has_context = np.array([len(c) > 0 for c in context])
        no_context = np.logical_not(has_context)
        idk = np.array([self.idk in r for r in responses])
        fact = np.logical_not(idk)
        idk_and_context = np.logical_and(idk, has_context)
        idk_and_no_context = np.logical_and(idk, no_context)
        fact_and_context = np.logical_and(fact, has_context)
        fact_and_no_context = np.logical_and(fact, no_context)
        # Accuracy = (IDK & NO Context + Response & Context) / All Responses
        accuracy = (idk_and_no_context.sum() + fact_and_context.sum()) / len(responses)
        hallucination_evaluation = {"accuracy": accuracy}
        print(f"Hallucination: {accuracy:.3f}")
        return hallucination_evaluation
    def bert(self, gold_answers: list, responses: list):
        precision, recall, f1 =  bert_score.score(responses, gold_answers, lang="en", verbose=True)
        bert_evaluation = {
            "precision": precision.mean().item(),
            "recall": recall.mean().item(),
            "f1": f1.mean().item()
        }
        print(f"BERT Score: {bert_evaluation['f1']:.3f}")
        return bert_evaluation
    def invoke(self, template, template_fill, generation_config):
        content = template.format(**template_fill)
        message = [{"role": "user", "content": content}]
        input_ids = self.tokenizer.apply_chat_template(
            message,
            return_tensors="pt",
            enable_thinking=False,
            add_generation_prompt=True
        ).to(self.model.device)

        with torch.no_grad():
            output = self.model.generate(**input_ids,generation_config=GenerationConfig(**generation_config))

        decoded_output = self.tokenizer.decode(output[0], skip_special_tokens=True)

        del input_ids
        del output
        gc.collect()
        torch.cuda.empty_cache()

        return self.extract(decoded_output)

    def extract(self, text_output):
        assistant_tag = "assistant"
        if assistant_tag in text_output:
            response_part = text_output.split(assistant_tag, 1)[1].strip()
            if "</think>" in response_part:
                response_part = response_part.split("</think>", 1)[1].strip()
        try:
            matches = re.findall(r"```(?:json)?\s*\n(.*?)\s*\n```", text_output, re.DOTALL)
            json_output = matches[-1]
            return json.loads(json_output)
        except Exception as e:
            print(f"Extraction error, regex failed to find JSON block.\nReturning empty dictionary.")
            print(text_output)
            raise e

# %%
import json
import time

def load(file_name):
    file_path = f"/content/drive/MyDrive/Colab Data/MIDS-267-A5/{file_name}.json"

    with open(file_path, "r") as f:
        file_contents = f.read()

        data = json.loads(file_contents)
        print(f"Successfully loaded {file_path}")
        return data

def save(json_dict, file_name):
    file_path = f"/content/drive/MyDrive/Colab Data/MIDS-267-A5/{file_name}_evaluation.json"

    with open(file_path, "w") as f:
        json.dump(json_dict, f, indent=4)

    print(f"Successfully saved {file_name} to {file_path}")

# %%
rag_evaluator = RAGEvaluator(
    tokenizer=qwen_tokenizer,
    model=qwen_model,
    embeddings=vector_store.embeddings,
    vector_store=vector_store,
    idk=IDK,
    claims_config = claims_config,
    persona_config = persona_config,
    relevancy_config = relevancy_config
)

file_name = "rag_eval_qas_2026-07-31 21:33:31"

eval_qas = load(file_name)

evaluation = rag_evaluator.evaluate(eval_qas)

save(evaluation, file_name)
# Out:
# Successfully loaded /content/drive/MyDrive/Colab Data/MIDS-267-A5/rag_eval_qas_2026-07-31 21:33:31.json
# Begin RAG Evaluation
# Question: How do language model pre-training tasks contribute to the effectiveness of open-domain question answering systems?
# Response: Language model pre-training tasks contribute to the effectiveness of open-domain question answering systems by enabling the model to answer questions based on "knowledge" that it internalized during pre-training. This is achieved through fine-tuning a pre-trained model to answer questions without access to any external context or knowledge.
# Gold Answer (research): Language model pre-training tasks play a crucial role in enhancing the effectiveness of open-domain question answering systems. By leveraging tasks such as Next Sentence Prediction (NSP) and domain-specific pre-training, models like BERT can better handle noisy and irrelevant contexts, leading to improved performance. Additionally, augmenting queries with relevant contexts can significantly enhance the unsupervised machine reading capabilities of pre-trained language models, ultimately improving their ability to provide accurate and up-to-date information for dynamic knowledge-intensive tasks.
# Faithful: 1.000
# Noisy: 0.000
# Persona: 0.800
# {'length': {'evaluation': 'The statement is concise and fits within the acceptable length preference, providing a clear and focused explanation without unnecessary elaboration. It effectively conveys the core mechanism without exceeding six sentences or becoming superficial.', 'score': 1}, 'vocabulary': {'evaluation': "The statement uses appropriate technical vocabulary such as 'pre-training tasks', 'fine-tuning', 'internalized', and 'external context', which are accurate and consistent with academic and research discourse.", 'score': 1}, 'technical_depth': {'evaluation': 'The statement touches on key technical concepts like pre-training, fine-tuning, and knowledge internalization, but it lacks explicit detail on the mechanisms (e.g., how pre-training tasks like masked language modeling or next-sentence prediction contribute to QA performance), specific methodologies, or empirical evidence. It is technically accurate but underdeveloped in depth.', 'score': 0}, 'relevant_topics': {'evaluation': 'The statement focuses on the technical mechanism of pre-training and fine-tuning in language models, which aligns with the core topics of methodology and model design in research contexts. It does not shift toward applications or business outcomes.', 'score': 1}, 'tone': {'evaluation': 'The tone is objective and analytical, avoiding promotional or speculative language. It presents a factual claim about model behavior grounded in standard research understanding.', 'score': 1}}
# Relevancy: 0.837
# ------
# Question: How do language model pre-training tasks contribute to the effectiveness of open-domain question answering systems?
# Response: Pre-training tasks are essential for the effectiveness of open-domain question answering systems. Two pre-training tasks are especially helpful for QA tasks.
# Gold Answer (marketing): Language model pre-training tasks contribute to the effectiveness of open-domain question answering systems by providing a foundation of knowledge and context for the model to build upon. This allows the model to better understand and generate answers to a wide range of questions. By fine-tuning the pre-trained model on specific tasks or domains, it can perform even better in answering questions accurately.
# Faithful: 1.000
# Noisy: 0.000
# Persona: 0.200
# {'length': {'evaluation': 'The statement is concise and directly addresses the point without unnecessary elaboration, fitting well within the acceptable 1–3 sentence length preference for marketing communication.', 'score': 1}, 'vocabulary': {'evaluation': "The statement uses technical terms like 'pre-training tasks' and 'open-domain question answering systems,' which are not accessible or user-friendly for general business audiences, making it overly academic and confusing for non-specialists.", 'score': 0}, 'technical_depth': {'evaluation': "The statement references specific technical concepts such as 'pre-training tasks' and 'open-domain QA systems,' which are methodologically grounded and not suitable for a general or business-oriented audience.", 'score': 0}, 'relevant_topics': {'evaluation': 'The statement focuses on internal technical mechanisms rather than practical benefits, usability, or real-world outcomes for end users or business stakeholders, missing the emphasis on value and performance expected in marketing communication.', 'score': 0}, 'tone': {'evaluation': 'The tone is neutral and descriptive, lacking the confident, positive, and solution-oriented tone that marketers prefer to position products or concepts as beneficial and accessible.', 'score': 0}}
# Relevancy: 0.765
# ------
# Question: What are the computational and practical trade-offs associated with deploying highly autonomous Agentic RAG systems compared to simpler, fixed-pipeline Enhanced RAG systems?
# Response: The computational and practical trade-offs associated with deploying highly autonomous Agentic RAG systems compared to simpler, fixed-pipeline Enhanced RAG systems are as follows:
#
# - The limitations of static RAG pipelines have become apparent as language models are increasingly deployed in complex, knowledge-intensive applications.
# - Reasoning Agentic RAG offers a promising path forward by integrating retrieval with model-driven planning, self-reflection, and tool use.
# - The paper surveyed the landscape of reasoning workflows within Agentic RAG, distinguishing between predefined reasoning with fixed orchestration, and agentic reasoning that enables dynamic, autonomous decision-making.
# - The paper reviewed key methods across both paradigms, highlighting their strengths, limitations, and use-case applicability.
# - To advance the field, the paper identifies several crucial directions for future research, including fine-grained reward design, enhanced tool control, automated data synthesis, and robust training in dynamic environments.
# - These innovations will be essential for realizing intelligent, context-aware RAG systems capable of addressing real-world challenges with greater adaptability, transparency, and reliability.
# Gold Answer (research): While Agentic RAG systems offer high flexibility by allowing the language model to autonomously orchestrate multiple retrieval and reasoning steps, this autonomy significantly increases monetary costs, token usage, and end-to-end latency. Empirical comparisons show that Agentic RAG can be several times more expensive and slower than Enhanced RAG pipelines, often without yielding universally superior retrieval performance in noisier domains. Consequently, experts warn against prematurely adopting complex agentic frameworks when simpler, highly optimized pipelines utilizing explicit re-rankers or straightforward API calls would adequately suffice for the specific product requirements.
# Faithful: 1.000
# Noisy: 0.000
# Persona: 1.000
# {'length': {'evaluation': 'The statement is concise and clearly structured, covering key points without unnecessary elaboration. It provides sufficient detail to explain the trade-offs and research landscape within agentic RAG systems, staying within the acceptable 6-sentence limit while maintaining clarity and logical flow.', 'score': 1}, 'vocabulary': {'evaluation': "The statement uses domain-specific and formal terminology such as 'agentic RAG', 'static RAG pipelines', 'model-driven planning', 'tool use', and 'dynamic, autonomous decision-making', all of which are appropriate and precise for a technical audience. There is no oversimplification or misuse of terms.", 'score': 1}, 'technical_depth': {'evaluation': 'The response includes methodological distinctions (e.g., predefined vs. agentic reasoning), references key research directions (e.g., fine-grained reward design, automated data synthesis), and touches on foundational concepts in RAG systems. It reflects a clear understanding of technical trade-offs and system design, demonstrating methodological awareness.', 'score': 1}, 'relevant_topics': {'evaluation': 'The statement centers on technical trade-offs, system design, methodology, and research directions—core elements of experimental and theoretical analysis in AI systems. It avoids shifting to business applications or user-facing outcomes, staying firmly grounded in technical and methodological considerations.', 'score': 1}, 'tone': {'evaluation': 'The tone is objective, analytical, and neutral, presenting a survey of existing work and identifying research directions without making speculative claims or promotional statements. It reflects a rigorous, evidence-based approach consistent with academic discourse.', 'score': 1}}
# Relevancy: 0.725
# ------
# Question: What are the computational and practical trade-offs associated with deploying highly autonomous Agentic RAG systems compared to simpler, fixed-pipeline Enhanced RAG systems?
# Response: The computational and practical trade-offs associated with deploying highly autonomous Agentic RAG systems compared to simpler, fixed-pipeline Enhanced RAG systems are unclear.
# Gold Answer (marketing): Agentic RAG systems can be more flexible because they allow AI to decide how to search for and combine information, but that flexibility often comes with higher costs and slower response times. In many cases, simpler RAG pipelines can deliver similar results more efficiently, so organizations should weigh the added complexity against the actual benefits.
# Faithful: 1.000
# Noisy: 0.000
# Persona: 0.800
# {'length': {'evaluation': 'The statement is concise and directly addresses a specific point without unnecessary elaboration, fitting within the acceptable 1–3 sentence length preference.', 'score': 1}, 'vocabulary': {'evaluation': 'The statement uses neutral, technically precise language appropriate for a professional audience but avoids overly complex or academic jargon, aligning with the acceptable business-friendly and accessible vocabulary preference.', 'score': 1}, 'technical_depth': {'evaluation': "The statement introduces technical concepts like 'Agentic RAG systems' and 'Enhanced RAG systems' which are specific to AI architecture, but does so at a high-level without diving into equations or internal mechanisms, thus staying within acceptable minimal-to-moderate technical depth.", 'score': 1}, 'relevant_topics': {'evaluation': 'The statement focuses on practical trade-offs in deployment, which relates to real-world usability and business decisions, making it relevant to end-user or stakeholder concerns rather than theoretical or internal mechanisms.', 'score': 1}, 'tone': {'evaluation': 'The tone is neutral and factual, which is acceptable for a technical observation, though it lacks the confident, positive, or solution-oriented tone preferred in marketing communication. It does not emphasize benefits or ease of use, which is a gap in marketing alignment.', 'score': 0}}
# Relevancy: 0.858
# ------
# Question: How can large language models be utilized to improve the process of selecting or filtering retrieved content in retrieval-augmented generation, and what specific benefits does this provide compared to traditional retrieval methods?
# Response: Retrieval-augmented generation (RAG) is a technique that enables large language models (LLMs) to retrieve and incorporate new information from external data sources. With RAG, LLMs first refer to a specified set of documents, then respond to user queries. These documents supplement information from the LLM's pre-existing training data. This allows LLMs to use domain-specific and/or updated information that is not available in the training data. For example, this enables LLM-based chatbots to access internal company data or generate responses based on authoritative sources. The technique was first proposed in 2020 and has since become a widely adopted approach in modern AI systems.
#
# RAG enhances LLMs by incorporating an information-retrieval mechanism that allows models to access and utilise additional data beyond their original training set. When new information becomes available, rather than having to retrain the model, all that's needed is to augment the model's external knowledge base with the updated information. In the generative phase, the LLM draws from the augmented prompt and its internal representation of its training data to synthesise an answer.
#
# The RAG model framework introduces a paradigm shift in generative AI by creating glass-box models. It greatly enhances the ability of generative models to provide accurate information, especially in knowledge-intensive domains. This minimises the risk of generating hallucinations or outdated information, enhances interpretability by clearly linking outputs to real-world sources, and enriches responses with relevant and accurate information.
# Gold Answer (research): Large language models can be utilized in retrieval-augmented generation by using their advanced natural language processing capabilities to understand and interpret the retrieved content. This allows for more precise selection or filtering of relevant information, improving the quality and accuracy of the generated output. Compared to traditional retrieval methods, this approach provides the benefit of leveraging contextual understanding and semantic relationships, resulting in more informed predictions and better performance in domain-specific or knowledge-intensive tasks.
# Faithful: 0.929
# Noisy: 0.071
# Persona: 1.000
# {'length': {'evaluation': 'The statement is comprehensive and provides a clear, structured explanation of RAG, covering its mechanism, function, and benefits. It elaborates on how RAG works, its integration with LLMs, and its advantages in terms of knowledge retrieval and hallucination reduction. The explanation is detailed enough to fully cover the technical concept without unnecessary tangents, fitting well within the acceptable length preference of up to six sentences with full technical depth.', 'score': 1}, 'vocabulary': {'evaluation': "The statement uses precise, domain-specific terminology such as 'retrieval-augmented generation', 'external data sources', 'transformer architectures', 'hallucinations', 'information-retrieval mechanism', and 'glass-box models'—all appropriate for a technical and academic audience. There is no oversimplification or misuse of terms; the language is formal and consistent with scientific discourse.", 'score': 1}, 'technical_depth': {'evaluation': "The response includes detailed technical explanations of how RAG functions—such as the two-phase process of retrieval and generation, the use of external knowledge bases, and the mechanism of avoiding retraining. It references key concepts like 'information-retrieval mechanism' and 'augmented prompt', and discusses theoretical and practical implications such as reducing hallucinations and improving interpretability. This level of methodological and conceptual detail aligns fully with the acceptable criteria for technical depth.", 'score': 1}, 'relevant_topics': {'evaluation': 'The statement centers on the technical mechanism of RAG, its integration with LLMs, the retrieval process, and its impact on model accuracy and interpretability—topics directly aligned with experimental design, methodology, and theoretical foundations. It does not shift focus to business applications or user experience, which would be unacceptable. Instead, it remains grounded in technical and empirical analysis.', 'score': 1}, 'tone': {'evaluation': "The tone is objective, analytical, and evidence-based. It presents RAG as a technically grounded innovation with clear functional and theoretical justifications, without making promotional claims or speculative assertions. Phrases like 'was first proposed in 2020' and 'minimises the risk of generating hallucinations' are factual and supported by established understanding in the field, reflecting a neutral and rigorous tone.", 'score': 1}}
# Relevancy: 0.724
# ------
# Question: How can large language models be utilized to improve the process of selecting or filtering retrieved content in retrieval-augmented generation, and what specific benefits does this provide compared to traditional retrieval methods?
# Response: Retrieval-Augmented Generation (RAG) is a promising solution to the challenges faced by Large Language Models (LLMs), such as hallucination, outdated knowledge, and non-transparent reasoning processes. RAG enhances the accuracy and credibility of generation by incorporating knowledge from external databases, allowing for continuous knowledge updates and the integration of domain-specific information.
# Gold Answer (marketing): Large language models can be used in retrieval-augmented generation to enhance the selection or filtering of retrieved content by providing more relevant and current information. This approach offers benefits like improved accuracy, efficiency, and effectiveness compared to traditional retrieval methods.
# Faithful: 1.000
# Noisy: 0.000
# Persona: 0.000
# {'length': {'evaluation': "The statement is moderately long, exceeding the acceptable 1–3 sentence limit and including a detailed explanation of RAG and its components. It introduces specific technical elements like 'hallucination', 'outdated knowledge', and 'non-transparent reasoning', which adds unnecessary length and depth for a marketing-oriented response.", 'score': 0}, 'vocabulary': {'evaluation': "The statement uses technical terms such as 'Retrieval-Augmented Generation', 'Large Language Models', 'hallucination', and 'domain-specific information' that are unfamiliar to general business audiences. These terms are inappropriate for a marketing context where accessible, user-friendly language is preferred.", 'score': 0}, 'technical_depth': {'evaluation': 'The statement includes detailed technical explanations about how RAG addresses internal model limitations, such as hallucination and non-transparent reasoning, which goes beyond minimal to moderate technical detail and leans into academic or research-level methodology.', 'score': 0}, 'relevant_topics': {'evaluation': 'The response focuses on internal mechanisms and technical limitations of LLMs rather than practical benefits, outcomes, or real-world usability. It lacks emphasis on how RAG improves business performance, user experience, or ease of use for end users or stakeholders.', 'score': 0}, 'tone': {'evaluation': 'The tone is neutral and descriptive, lacking the confident, positive, and solution-oriented tone that marketers prefer. It does not position RAG as a valuable, accessible, or beneficial tool for businesses or users.', 'score': 0}}
# Relevancy: 0.760
# ------
# Question: What challenges can arise from relying solely on automated or AI-based evaluation methods?
# Response: [IDK]
# Gold Answer (research): Relying solely on automated or AI-based evaluation methods can lead to challenges such as biases in the outputs, irrelevance, toxicity, or bias in the responses, disjointed or incoherent outputs when integrating retrieved information with different tasks, redundancy in responses when similar information is retrieved from multiple sources, and subjective preferences impacting the evaluation process. Additionally, automated evaluation systems may have noticeable biases and may not always provide accurate assessments of the AI applications. It is important to supplement automated evaluation with human evaluation to ensure comprehensive and reliable feedback on the product's performance.
# Faithful: 0.000
# Noisy: 0.000
# Persona: skipping [IDK] response
# Persona: 0.000
# {'length': {'evaluation': "The statement 'IDK' provides no meaningful content and fails to meet the acceptable length criteria, as it offers no explanation, structure, or detail required for a technically rigorous response.", 'score': 0}, 'vocabulary': {'evaluation': 'The statement uses no technical vocabulary and avoids all domain-specific terminology, which is unacceptable for a researcher who expects precise and formal academic language.', 'score': 0}, 'technical_depth': {'evaluation': 'The statement lacks any technical detail, methodology, or explanation of mechanisms, failing to provide any evidence-based or theoretical foundation required by researchers.', 'score': 0}, 'relevant_topics': {'evaluation': 'The statement does not address any technical topics such as models, training, data, or mechanisms, and thus fails to focus on experimental design, methodology, or theoretical frameworks.', 'score': 0}, 'tone': {'evaluation': 'The statement is neither objective nor analytical; it is vague, unformed, and lacks any evidence-based reasoning, making it subjective and unsuitable for a research-oriented context.', 'score': 0}}
# Relevancy: 0.383
# ------
# Question: What challenges can arise from relying solely on automated or AI-based evaluation methods?
# Response: A common pitfall is forgoing human evaluation to rely entirely on AI judges. While AI judges can be very useful, they aren’t deterministic. The quality of a judge depends on the underlying judge’s model, the judge’s prompt, and the use case. If the AI judge isn’t developed properly, it can give misleading evaluations about your application’s performance.
# Gold Answer (marketing): Relying solely on automated or AI-based evaluation methods can lead to biased, irrelevant, or toxic outputs, which can lower the quality and reliability of responses. Without human evaluation, integration of retrieved information can be challenging, resulting in disjointed or repetitive outputs. Additionally, subjective preferences may play a significant role, impacting the accuracy and relevance of the evaluations.
# Faithful: 1.000
# Noisy: 0.000
# Persona: 0.000
# {'length': {'evaluation': 'The statement is moderately long, providing a detailed explanation of a potential pitfall in AI evaluation. While it is not excessively verbose, it goes beyond the preferred 1–3 sentence limit for marketing communication, introducing a nuanced discussion about model dependencies and use cases.', 'score': 0}, 'vocabulary': {'evaluation': "The statement uses technical terms such as 'deterministic', 'underlying judge’s model', and 'use case' which are not accessible to general business audiences. These terms are academic and may alienate non-specialist stakeholders, violating the preference for business-friendly and user-oriented language.", 'score': 0}, 'technical_depth': {'evaluation': 'The statement includes methodological and technical details about AI judge development, model dependencies, and prompt design, which are not relevant to end users or business stakeholders. This level of technical depth is unacceptable for marketing communication.', 'score': 0}, 'relevant_topics': {'evaluation': 'The statement focuses on technical limitations of AI judges rather than benefits, outcomes, or real-world applicability. It lacks emphasis on practical value, usability, or performance for end users or businesses, missing the focus on practical outcomes and user experience.', 'score': 0}, 'tone': {'evaluation': 'The tone is neutral and cautionary, discussing risks and limitations without a confident, positive, or solution-oriented stance. It lacks the persuasive intent and enthusiasm expected in marketing communication.', 'score': 0}}
# Relevancy: 0.683
# ------
# Question: Which benchmark is described as a hierarchical and comprehensive safety benchmark for large language models?
# Response: The benchmark described as a hierarchical and comprehensive safety benchmark for large language models is Salad-bench.
# Gold Answer (research): The hierarchical and comprehensive safety benchmark for large language models described in the given context is called WriteBench. It is designed to assess the writing capabilities of LLMs across multiple domains and tasks, ensuring a fair comparison between Weaver and other generalist LLMs. WriteBench will be publicly available for evaluation purposes on GitHub at https://github.com/aiwaves-cn/WriteBench.
# Faithful: 1.000
# Noisy: 0.000
# Persona: 0.000
# {'length': {'evaluation': "The statement is concise and provides only a brief factual assertion without elaboration on mechanisms, methodology, or empirical evidence. It fails to meet the acceptable length criterion as it does not offer a detailed explanation or structured breakdown of the benchmark's design or technical components.", 'score': 0}, 'vocabulary': {'evaluation': "The statement uses simple, general vocabulary such as 'hierarchical and comprehensive safety benchmark' without domain-specific or technical terminology appropriate for a research audience. It lacks precise academic or technical phrasing expected in scientific discourse.", 'score': 0}, 'technical_depth': {'evaluation': 'The statement offers no explanation of the underlying methodology, experimental design, or theoretical framework of Salad-bench. It lacks any detail on how the benchmark evaluates safety, measures risks, or assesses model behavior under various conditions, which is essential for technical rigor.', 'score': 0}, 'relevant_topics': {'evaluation': 'The statement does not address experimental design, performance metrics, trade-offs, or theoretical foundations. It merely names a benchmark without any technical or methodological context, thus failing to focus on the core technical topics researchers value.', 'score': 0}, 'tone': {'evaluation': 'The tone is neutral and factual, which is acceptable. However, it lacks analytical depth and evidence-based reasoning, making it more descriptive than analytical. While not overtly promotional, it does not reflect the objective, evidence-based tone required for rigorous research communication.', 'score': 0}}
# Relevancy: 0.938
# ------
# Question: Which benchmark is described as a hierarchical and comprehensive safety benchmark for large language models?
# Response: The benchmark described as a hierarchical and comprehensive safety benchmark for large language models is called Salad-bench.
# Gold Answer (marketing): The Massively Multitask Language Understanding (MMLU) benchmark is described as a hierarchical and comprehensive safety benchmark for large language models.
# Faithful: 1.000
# Noisy: 0.000
# Persona: 0.600
# {'length': {'evaluation': 'The statement is concise and fits within the acceptable 1–3 sentence length preference. It delivers the key information clearly without unnecessary elaboration.', 'score': 1}, 'vocabulary': {'evaluation': "The vocabulary is accessible and avoids overly technical or academic terms. Terms like 'hierarchical and comprehensive safety benchmark' are somewhat technical but used in a straightforward way that a general business audience can grasp without deep expertise.", 'score': 1}, 'technical_depth': {'evaluation': 'The statement includes minimal technical detail, focusing on the name and basic definition of Salad-bench without diving into methodology or architecture. This aligns with the acceptable preference for minimal to moderate technical detail.', 'score': 1}, 'relevant_topics': {'evaluation': 'The statement focuses on the name and nature of a benchmark, which is relevant to understanding safety evaluation tools in AI. While not explicitly benefit-focused, it provides foundational context useful for stakeholders in AI safety or product development, making it relevant to practical applications.', 'score': 0}, 'tone': {'evaluation': 'The tone is neutral and factual, lacking the confident, positive, or solution-oriented tone preferred in marketing communication. It does not emphasize benefits or practical value for end users or businesses.', 'score': 0}}
# Relevancy: 0.953
# ------
# Question: What are some of the main challenges that Retrieval-Augmented Generation aims to address when applied to large language models, and how does integrating external knowledge bases help overcome these obstacles?
# Response: Retrieval-Augmented Generation (RAG) aims to address several challenges when applied to large language models (LLMs), including hallucination, outdated knowledge, and non-transparent, untraceable reasoning processes. These issues arise due to the static nature of LLMs' training data, which can lead to incomplete or inaccurate responses.
#
# RAG integrates knowledge from external databases, enhancing the accuracy and credibility of generation, particularly for knowledge-intensive tasks. This integration allows for continuous knowledge updates and the incorporation of domain-specific information. By merging LLMs' intrinsic knowledge with external databases, RAG improves the models' adaptability and cross-lingual capabilities.
#
# Integrating external knowledge bases helps overcome these challenges by providing factual grounding and improving factual accuracy, interpretability, and logical consistency. External retrieval leverages structured sources like databases or web content, while in-context retrieval utilises internal contexts like prior interactions or training examples. This collective approach enhances contextual coherence and enables LLMs to address complex queries by grounding reasoning steps in verified external evidence.
# Gold Answer (research): Retrieval-Augmented Generation (RAG) aims to address challenges such as hallucination, outdated knowledge, and non-transparent reasoning processes in large language models. By incorporating knowledge from external databases, RAG enhances accuracy and credibility in generation tasks, particularly for knowledge-intensive tasks. The integration of external knowledge bases helps provide real-time, relevant information to the generative model, improving the quality of the outputs and mitigating issues related to outdated or erroneous information in the model itself.
# Faithful: 1.000
# Noisy: 0.000
# Persona: 1.000
# {'length': {'evaluation': 'The statement is comprehensive and detailed, covering multiple aspects of RAG, including its purpose, the challenges it addresses, integration mechanisms, and technical components like in-context and external retrieval. It provides sufficient depth to explain the technical underpinnings without being unnecessarily verbose, staying within the acceptable 6-sentence limit while maintaining clarity and structure.', 'score': 1}, 'vocabulary': {'evaluation': "The statement uses precise, domain-specific terminology such as 'hallucination', 'factual grounding', 'in-context retrieval', 'external databases', 'transformer architectures', and 'cross-lingual capabilities', all appropriate for a technical and academic audience. There is no oversimplification or misuse of terms.", 'score': 1}, 'technical_depth': {'evaluation': 'The response includes detailed explanations of how RAG addresses key technical issues like hallucination and lack of transparency, references specific mechanisms (e.g., external databases, in-context retrieval), and discusses integration with LLMs. It touches on methodological foundations such as knowledge integration, factual accuracy, and interpretability, demonstrating a strong grasp of the underlying technical and empirical aspects.', 'score': 1}, 'relevant_topics': {'evaluation': 'The statement centers on technical aspects such as model limitations, retrieval mechanisms, knowledge integration, and reasoning transparency—core topics in the methodology and performance of LLMs. It does not shift focus to business applications or user experience, remaining firmly grounded in technical analysis and empirical reasoning.', 'score': 1}, 'tone': {'evaluation': "The tone is objective, analytical, and evidence-based, presenting RAG's benefits and mechanisms without subjective claims or promotional language. It remains neutral and focused on technical reasoning and foundational principles, consistent with academic and research-oriented discourse.", 'score': 1}}
# Relevancy: 0.727
# ------
# Question: What are some of the main challenges that Retrieval-Augmented Generation aims to address when applied to large language models, and how does integrating external knowledge bases help overcome these obstacles?
# Response: Retrieval-Augmented Generation (RAG) aims to address challenges like hallucination, outdated knowledge, and non-transparent, untraceable reasoning processes. Integrating external knowledge bases helps overcome these obstacles by enhancing the accuracy and credibility of the generation, particularly for knowledge-intensive tasks. It allows for continuous knowledge updates and integration of domain-specific information.
# Gold Answer (marketing): Retrieval-Augmented Generation aims to address challenges like hallucination, outdated knowledge, and non-transparency in large language models. By incorporating external knowledge bases, RAG enhances accuracy, credibility, and the overall quality of generated outputs for knowledge-intensive tasks.
# Faithful: 1.000
# Noisy: 0.000
# Persona: 0.000
# {'length': {'evaluation': "The statement is longer than the acceptable 1–3 sentence limit, providing a detailed explanation that goes beyond concise, benefit-focused communication. It includes specific technical elements like 'hallucination', 'outdated knowledge', and 'non-transparent reasoning', which adds unnecessary length and depth for a marketing-oriented response.", 'score': 0}, 'vocabulary': {'evaluation': "The statement uses technical terms such as 'retrieval-augmented generation', 'hallucination', 'knowledge bases', and 'domain-specific information', which are not accessible to general business audiences. These terms are alienating and inappropriate for a marketing context where user-friendly language is preferred.", 'score': 0}, 'technical_depth': {'evaluation': 'The statement includes detailed technical concepts such as internal mechanisms of RAG, knowledge base integration, and issues like hallucination and transparency. This level of methodological detail is unacceptable for marketing communication, which should avoid complex technical explanations.', 'score': 0}, 'relevant_topics': {'evaluation': 'The statement focuses on internal mechanisms and technical limitations rather than practical benefits or real-world applications. It lacks emphasis on user outcomes, usability, or business value, which are central to marketing communication preferences.', 'score': 0}, 'tone': {'evaluation': 'The tone is neutral and descriptive, lacking the confident, positive, and solution-oriented tone expected in marketing communication. It does not position the concept as beneficial or accessible to end users or stakeholders.', 'score': 0}}
# Relevancy: 0.678
# ------
# Question: Which technique proposed by Zheng et al. (2023) involves invoking the judge LLM twice and swapping the order of two candidates to mitigate positional bias in LLM-based evaluation systems?
# Response: Zheng et al. (2023) propose a swapping operation, which involves invoking the judge LLM twice, swapping the order of the two candidates in each instance. If the two results are inconsistent, it is labelled a "tie", indicating that the LLM is unable to confidently distinguish the quality of the candidates.
# Gold Answer (research): The technique proposed by Zheng et al. (2023) to mitigate positional bias in LLM-based evaluation systems involves a swapping operation. This operation includes invoking the judge LLM twice and swapping the order of the two candidates in each instance. If the results from the two invocations are inconsistent, it is labeled a "tie," indicating the LLM's inability to confidently distinguish the quality of the candidates. This swapping operation technique is widely adopted in pairwise feedback synthesis to improve the accuracy of reward signals.
# Faithful: 1.000
# Noisy: 0.000
# Persona: 1.000
# {'length': {'evaluation': 'The statement is concise and fits within the acceptable length limit, providing a clear and sufficient explanation of the swapping operation without unnecessary elaboration. It effectively conveys the key technical mechanism without exceeding six sentences.', 'score': 1}, 'vocabulary': {'evaluation': "The statement uses appropriate technical vocabulary such as 'swapping operation', 'invoking the judge LLM', 'candidates', 'inconsistent', and 'tie', all of which are precise and consistent with academic and methodological discourse in AI evaluation literature.", 'score': 1}, 'technical_depth': {'evaluation': 'The statement clearly explains the mechanism of the swapping operation, references the use of LLMs in judgment, and describes the condition for labeling a tie based on inconsistent results—demonstrating a strong understanding of the experimental design and decision logic.', 'score': 1}, 'relevant_topics': {'evaluation': 'The response focuses on the experimental design and the mechanism of how ties are determined in a pairwise evaluation setting, which aligns directly with methodological and technical analysis in AI research.', 'score': 1}, 'tone': {'evaluation': 'The tone is objective, neutral, and descriptive, presenting the method without speculation or promotional language, consistent with the evidence-based and analytical expectations of researchers.', 'score': 1}}
# Relevancy: 0.682
# ------
# Question: Which technique proposed by Zheng et al. (2023) involves invoking the judge LLM twice and swapping the order of two candidates to mitigate positional bias in LLM-based evaluation systems?
# Response: The technique proposed by Zheng et al. (2023) is called the 'swapping operation'. It involves invoking the judge LLM twice, swapping the order of the two candidates in each instance. If the two results are inconsistent, it is labelled a 'tie', indicating that the LLM is unable to confidently distinguish the quality of the candidates.
# Gold Answer (marketing): The technique proposed by Zheng et al. (2023) is the swapping operation, which involves invoking the judge LLM twice and swapping the order of the two candidates to mitigate positional bias in LLM-based evaluation systems.
# Faithful: 1.000
# Noisy: 0.000
# Persona: 0.000
# {'length': {'evaluation': 'The statement is longer than 3 sentences and includes detailed procedural explanation of a technical method, which goes beyond the acceptable length preference for marketing communication.', 'score': 0}, 'vocabulary': {'evaluation': "The statement uses technical terms such as 'judge LLM', 'swapping operation', 'candidates', and 'inconsistent' that are unfamiliar to non-specialists and lack business-friendly or user-oriented language.", 'score': 0}, 'technical_depth': {'evaluation': 'The statement includes specific methodological details about invoking an LLM twice and defining ties based on inconsistent results, which is inappropriate for a marketing audience and exceeds acceptable technical depth.', 'score': 0}, 'relevant_topics': {'evaluation': 'The statement focuses on internal technical mechanisms and methodology rather than practical benefits, usability, or real-world business outcomes, which misaligns with marketing communication preferences.', 'score': 0}, 'tone': {'evaluation': 'The tone is neutral and descriptive, lacking confidence, positivity, or persuasive intent that is expected in marketing communication.', 'score': 0}}
# Relevancy: 0.784
# ------
# Question: How have pretrained transformer models such as BERT influenced advancements in text ranking methods?
# Response: Pretrained transformer models such as BERT have influenced advancements in text ranking methods by providing a foundation for the development of new techniques. For example, the QASPER model is based on pretrained Transformer models, which produce state-of-the-art results on a majority of QA tasks. The model includes a variety of answer types, including extractive, abstractive, yes/no, and unanswerable questions, which are converted into a single task: generating answer text. This is a sequence-to-sequence formulation that requires an encoder-decoder Transformer model where the encoder reads the question and the document and the decoder generates the answer text.
#
# The BART model is pre-trained on the same corpora as BERT, namely Wikipedia and Toronto Books, and may retain some inherent knowledge within its parameters. BART-Large, a 400m parameter model, serves as the base seq2seq model for RAG in Lewis et al. (2020b).
#
# The T5 model proposes another method of pre-training Transformers for transfer learning, via converting several language tasks into “text-to-text” tasks. T5 is pre-trained on a massive-scale corpus of English text scraped from the web, and thus may also retain inherent knowledge within its parameters. T5-Base (220m parameters) and T5-Large (770m parameters) are both used in the FiD setup (Izacard and Grave, 2020).
#
# The BlenderBot model is a large-scale open-domain dialogue model, which is pre-trained on a massive-scale corpus of English text scraped from the web. It may also retain inherent knowledge within its parameters.
#
# Multi-passage BERT implemented an independent passage ranker model via another BERT model and the rank score for $(x, z)$ is generated by a softmax over the representation vectors of the first [CLS] token. The passage ranker brings in extra 2% improvements. Similar ideas of re-ranking passages with BERT were discussed in Nogueira & Cho, 2019, too.
#
# Interestingly, Wang et al., 2019 found that explicit inter-sentence matching does not seem to be critical for RC tasks with BERT; check the original paper for how the experiments were designed. One possible reason is that the multi-head self-attention layers in BERT has already embedded the inter-sentence matching.
#
# The retriever and reader components can be jointly trained. This section covers R^3, ORQA, REALM and DPR. There are a lot of common designs, such as BERT-based dense vectors for retrieval and the loss function on maximizing the marginal likelihood of obtaining true answers.
# Gold Answer (research): Pretrained transformer models like BERT have significantly advanced text ranking methods by incorporating additional knowledge through pre-training models. These models have enhanced language models by improving contextual representations, such as replacing original position encodings with RoPE during pre-training. Additionally, models like RoBERTa have optimized pre-training recipes and improved task performance without introducing many more trainable parameters, leading to better text ranking results. The use of transformers in text ranking has revolutionized NLP tasks and achieved state-of-the-art performance in various benchmarks.
# Faithful: 0.857
# Noisy: 0.000
# Persona: 1.000
# {'length': {'evaluation': 'The statement is comprehensive and detailed, covering multiple models (BERT, QASPER, BART, T5, BlenderBot, Multi-passage BERT) and their technical implementations, including pre-training corpora, model architectures, and performance impacts. It stays within the acceptable 6-sentence limit while providing sufficient depth on mechanisms and experimental setups without unnecessary expansion.', 'score': 1}, 'vocabulary': {'evaluation': "The statement uses precise, domain-specific terminology such as 'pretrained transformer models', 'encoder-decoder', 'multi-head self-attention', 'sequence-to-sequence formulation', 'softmax', 'marginal likelihood', and 'retriever and reader components'. These terms are appropriate for a technical audience and reflect academic discourse.", 'score': 1}, 'technical_depth': {'evaluation': 'The response includes detailed technical explanations of model architectures, training procedures, and mechanisms such as inter-sentence matching, dense vector retrieval, and loss functions. It references specific papers and models with clear attention to methodology and experimental design, demonstrating a strong grounding in empirical and theoretical foundations.', 'score': 1}, 'relevant_topics': {'evaluation': 'The content centers on technical aspects such as model design, training data, architectural choices, performance metrics (e.g., 2% improvement), and theoretical mechanisms (e.g., self-attention layers). It avoids business or application-focused claims and remains firmly rooted in experimental and methodological analysis.', 'score': 1}, 'tone': {'evaluation': "The tone is objective, analytical, and evidence-based. It presents technical claims with references to prior work and avoids promotional language. Statements like 'may retain some inherent knowledge' and 'one possible reason is...' reflect cautious, evidence-informed reasoning typical of academic discourse.", 'score': 1}}
# Relevancy: 0.762
# ------
# Question: How have pretrained transformer models such as BERT influenced advancements in text ranking methods?
# Response: Pretrained transformer models such as BERT have influenced advancements in text ranking methods by providing a mapping from corrupted documents to their original representations.
# Gold Answer (marketing): Pretrained transformer models like BERT have revolutionized text ranking methods by enhancing language models with additional knowledge through pre-training techniques. They have improved performance in tasks such as reranking passages using rule-based or model-based approaches, resulting in more precise language model processing. The use of BERT and similar models has led to significant advancements in text ranking methods by optimizing dense retrieval model training with hard negatives and achieving high accuracy in identifying answer spans.
# Faithful: 0.500
# Noisy: 0.500
# Persona: 0.000
# {'length': {'evaluation': 'The statement is concise but leans toward technical detail and lacks a clear benefit-focused outcome, making it slightly longer than ideal for marketing preferences. It does not explicitly address end-user value or practical application.', 'score': 0}, 'vocabulary': {'evaluation': "The statement uses technical terms like 'pretrained transformer models', 'BERT', 'text ranking methods', and 'corrupted documents' which are unfamiliar to non-specialists and not user-oriented.", 'score': 0}, 'technical_depth': {'evaluation': 'The statement includes specific technical concepts such as BERT and document representation mapping, which are not necessary for general understanding and go beyond acceptable technical depth for marketing audiences.', 'score': 0}, 'relevant_topics': {'evaluation': 'The statement focuses on internal technical mechanisms (e.g., mapping corrupted documents to original representations) rather than practical benefits, usability, or real-world business outcomes.', 'score': 0}, 'tone': {'evaluation': 'The tone is neutral and academic, lacking the confidence, positivity, and solution-oriented approach that marketers prefer to position products as beneficial and accessible.', 'score': 0}}
# Relevancy: 0.770
# ------
# Question: How does the automatic evaluation process using ChatGPT and Llama 3 distinguish between partially correct, completely correct, and incorrect responses, and how are these classifications reflected in their accuracy and F1 scores?
# Response: The automatic evaluation process uses a two-step method: if the answer matches the ground truth exactly, it is considered accurate; otherwise, LLMs are used to determine whether the response is accurate, incorrect, or missing. To avoid the self-preference problem, two LLM evaluators are used: ChatGPT (gpt-3.5-turbo-0125) and Llama 3 (llama-3-70B-instruct). The average accurate, hallucination, missing rates, and truthfulness scores from the two models are reported for each RAG system. The offline experiment shows that this two-step method yields an average F1 score of 94.7% for ChatGPT and 98.9% for Llama 3 compared to human-eval.
# ...
# Relevancy: 0.812
# ------
# Question: What are the primary differences between white-box and black-box adversarial attacks?
# Response: White-box attacks assume that attackers have full access to the model weights, architecture and training pipeline, such that attackers can obtain gradient signals. We don’t assume attackers have access to the full training data. This is only possible for open-sourced models.
#
# Black-box attacks assume that attackers only have access to an API-like service where they provide input x and get back sample y, without knowing further information about the model.
# Gold Answer (research): White-box attacks involve attackers having full access to the model architecture, weights, and training pipeline, allowing them to obtain gradient signals for adversarial attacks. On the other hand, black-box attacks assume attackers only have access to an API-like service without detailed information about the model. White-box attacks typically require knowledge of the model's internal workings, while black-box attacks rely on external input-output interactions with the model, making them more challenging to execute. Additionally, white-box attacks often result in nonsensical prompts and can be detected by examining perplexity, whereas black-box attacks may use token manipulation or jailbreak prompting to trigger model failures while retaining semantic meanings.
# Faithful: 0.667
# Noisy: 0.333
# Persona: 1.000
# {'length': {'evaluation': 'The statement is concise and fits within the acceptable length preference, providing a clear and structured explanation of white-box and black-box attacks without unnecessary elaboration. It covers the essential technical distinctions without exceeding six sentences, maintaining clarity and completeness.', 'score': 1}, 'vocabulary': {'evaluation': "The statement uses precise and appropriate technical terminology such as 'white-box attacks', 'black-box attacks', 'gradient signals', 'model weights', 'architecture', 'training pipeline', and 'API-like service', all of which are standard in machine learning security literature. The vocabulary is formal and domain-specific, matching academic discourse.", 'score': 1}, 'technical_depth': {'evaluation': 'The response includes key technical distinctions relevant to adversarial machine learning, such as access to model internals versus API-only access, and explicitly references gradient signals and training pipelines. It accurately reflects the methodological foundations of these attack types, demonstrating understanding of the underlying mechanisms and assumptions.', 'score': 1}, 'relevant_topics': {'evaluation': 'The statement focuses on the technical assumptions and mechanisms of adversarial attack models, specifically addressing access levels and their implications on attack feasibility. This aligns with the acceptable preference for discussing methodology, attack models, and technical assumptions rather than applications or business outcomes.', 'score': 1}, 'tone': {'evaluation': 'The tone is objective, neutral, and analytical, presenting factual distinctions between attack types without speculation or promotional language. It reflects a technical, evidence-based perspective consistent with academic or research-oriented communication.', 'score': 1}}
# Relevancy: 0.788
# ------
# Question: What are the primary differences between white-box and black-box adversarial attacks?
# Response: White-box attacks assume that attackers have full access to the model weights, architecture and training pipeline, such that attackers can obtain gradient signals. Black-box attacks assume that attackers only have access to an API-like service where they provide input x and get back sample y, without knowing further information about the model.
# Gold Answer (marketing): White-box attacks have full access to model details like weights and architecture, while black-box attacks only have access to input-output interface like an API. White-box attacks are more powerful but black-box attacks are based on limited information.
# Faithful: 1.000
# Noisy: 0.000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2754/590113191.py in <cell line: 0>()
#      14 eval_qas = load(file_name)
#      15
# ---> 16 evaluation = rag_evaluator.evaluate(eval_qas)
#      17
#      18 save(evaluation, file_name)
#
# /tmp/ipykernel_2754/3346512601.py in evaluate(self, eval_qas)
#      40             print(f"Gold Answer ({persona['name']}): {gold_answer}")
#      41             self.claims(response, context)
# ---> 42             self.persona(response, persona['description'])
#      43             self.relevancy(response, question)
#      44             print("------")
#
# /tmp/ipykernel_2754/3346512601.py in persona(self, response, persona)
#     105         template = self.persona_config['template']
#     106         generation_config = self.persona_config['generation_config']
# --> 107         persona_evaluation = self.invoke(template, template_fill, generation_config)
#     108         persona_scores = [1 if float(x['score']) >= 0.5 else 0 for x in persona_evaluation.values()]
#     109         persona_score = np.mean(persona_scores)
#
# /tmp/ipykernel_2754/3346512601.py in invoke(self, template, template_fill, generation_config)
#     161
#     162         with torch.no_grad():
# --> 163             output = self.model.generate(**input_ids,generation_config=GenerationConfig(**generation_config))
#     164
#     165         decoded_output = self.tokenizer.decode(output[0], skip_special_tokens=True)
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     122         # pyrefly: ignore [bad-context-manager]
#     123         with ctx_factory():
# --> 124             return func(*args, **kwargs)
#     125
#     126     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, custom_generate, **kwargs)
#    2679
#    2680         # 9. Call generation mode
# -> 2681         result = decoding_method(
#    2682             self,
#    2683             input_ids,
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    2893                         input_ids, next_sequence_length=next_sequence_length, **model_kwargs
#    2894                     )
# -> 2895                     outputs = model_forward(**model_inputs, return_dict=True)
#    2896                 prefill_consumed = True
#    2897                 model_kwargs = self._update_model_kwargs_for_generation(
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#     909         if return_dict_passed is not None:
#     910             return_dict = return_dict_passed
# --> 911         output = func(self, *args, **kwargs)
#     912         if not return_dict and not isinstance(output, tuple):
#     913             output = output.to_tuple()
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/qwen3/modeling_qwen3.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, logits_to_keep, **kwargs)
#     490         "Hey, are you conscious? Can you talk to me?\nI'm not conscious, but I can talk to you."
#     491         ```"""
# --> 492         outputs: BaseModelOutputWithPast = self.model(
#     493             input_ids=input_ids,
#     494             attention_mask=attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#    1038                     output = func(self, *args, **kwargs)
#    1039             else:
# -> 1040                 output = func(self, *args, **kwargs)
#    1041         # Restore original config value
#    1042         finally:
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/output_capturing.py in wrapper(self, *args, **kwargs)
#     260             # Run the forward
#     261             try:
# --> 262                 outputs = func(self, *args, **kwargs)
#     263             # Reset the states
#     264             finally:
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/qwen3/modeling_qwen3.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, **kwargs)
#     422
#     423         for i, decoder_layer in enumerate(self.layers[: self.config.num_hidden_layers]):
# --> 424             hidden_states = decoder_layer(
#     425                 hidden_states,
#     426                 attention_mask=causal_mask_mapping[self.config.layer_types[i]],
#
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_layers.py in __call__(self, *args, **kwargs)
#     108
#     109             return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# --> 110         return super().__call__(*args, **kwargs)
#     111
#     112
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/qwen3/modeling_qwen3.py in forward(self, hidden_states, attention_mask, position_ids, past_key_values, use_cache, position_embeddings, **kwargs)
#     330         residual = hidden_states
#     331         hidden_states = self.post_attention_layernorm(hidden_states)
# --> 332         hidden_states = self.mlp(hidden_states)
#     333         hidden_states = residual + hidden_states
#     334         return hidden_states
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/qwen3/modeling_qwen3.py in forward(self, x)
#      80
#      81     def forward(self, x):
# ---> 82         down_proj = self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))
#      83         return down_proj
#      84
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1777             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#    1781     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1788                 or _global_backward_pre_hooks or _global_backward_hooks
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#    1792         result = None
#
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/nn/modules.py in forward(self, x)
#     635             bias = bias.to(self.compute_dtype)
#     636
# --> 637         return bnb.matmul_4bit(x, self.weight, bias=bias, quant_state=quant_state).to(inp_dtype)
#     638
#     639
#
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/autograd/_functions.py in matmul_4bit(A, B, quant_state, out, bias)
#     470             )
#     471         elif quant_state.state2.blocksize == 256:
# --> 472             result = torch.ops.bitsandbytes.gemm_4bit.default(
#     473                 A,
#     474                 B,
#
# /usr/local/lib/python3.12/dist-packages/torch/_ops.py in __call__(self, *args, **kwargs)
#     863     # that are named "self". This way, all the aten ops can be called by kwargs.
#     864     def __call__(self, /, *args: _P.args, **kwargs: _P.kwargs) -> _T:
# --> 865         return self._op(*args, **kwargs)
#     866
#     867     # Use positional-only argument to avoid naming collision with aten ops arguments
#
# /usr/local/lib/python3.12/dist-packages/torch/_compile.py in inner(*args, **kwargs)
#      40     if fn is not None:
#      41
# ---> 42         @functools.wraps(fn)
#      43         def inner(*args: _P.args, **kwargs: _P.kwargs) -> _T:
#      44             # cache this on the first invocation to avoid adding too much overhead.
#
# KeyboardInterrupt:
